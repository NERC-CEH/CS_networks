# %% [markdown]
# # Today I will talk about...
#
# - Using git in DataLabs (focusing on GUI options)
# - Running 'local' jobs
#
# NB: all the above you can do on a local machine. But there are some beneifts to use them in DataLabs.

# %% [markdown]
# ## Using git in DataLabs
# - Linux terminal (available in both R studio and Jupyter Lab)
# - R studio (GUI)
# - Jupyter Lab (GUI)
#
# Further reading: [Happy Git and GitHub for the useR](https://happygitwithr.com/)
#
# Diagrams that explains git: http://marklodato.github.io/visual-git-guide/index-en.html
#
# https://docs.github.com/en/free-pro-team@latest/github/importing-your-projects-to-github/adding-an-existing-project-to-github-using-the-command-line
#
# ### Using git in R studio (GUI)
# - open as new R studio project using version control
#
# ![image.png](attachment:15782e22-f99e-40b9-82a1-8cb2e4190cdd.png)
#
# ### Using git in Jupyter Lab (GUI)
# ![image.png](attachment:e8aca396-1e82-48ef-8c5a-139e957936ac.png)

# %% [markdown]
# ![](https://raw.githubusercontent.com/jupyterlab/jupyterlab-git/HEAD/docs/figs/preview.gif)

# %% [markdown]
# ## Running local jobs in RStudio

# %% [markdown]
# ![image.png](attachment:84e6ff13-06a1-4d46-918e-e5bada3e1b4e.png)
